# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import psycopg2
from config import db_password
import pandas as pd

# %%
connection_string = f'postgresql://postgres:{db_password}@127.0.0.1:5432/olympics'

# %%
# Database Setup
engine = create_engine(connection_string)

# %%
# Create the session from Python to the DB
session = Session(engine)

# %%
# Create dataframe with filtered csv
df = pd.read_csv('data/athlete_events_after1960.csv')

# %%
# Drops all any rows with NA
df = df.dropna()

# %%
df['Name'].str.replace('"','')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 3            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 4            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 199832  135569                Andrzej ya   M  29.0   179.0    89.0
# 199833  135570                  Piotr ya   M  27.0   176.0    59.0
# 199834  135570                  Piotr ya   M  27.0   176.0    59.0
# 199835  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 199836  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 0             China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.to_sql(name='athletes', con=engine)

# %%
#df = pd.read_sql_query('select * from "athlete_data"',con=engine)
#df

# %%
# query 
#results = session.query(#...)

# %%
noc_df = pd.read_csv('data/host_cities.csv')
noc_df
# Out:
#                  Host City Host Country
# 0                Barcelona          ESP
# 1                   London          GBR
# 2                Antwerpen          BEL
# 3                    Paris          FRA
# 4                  Calgary          CAN
# 5              Albertville          FRA
# 6              Lillehammer          NOR
# 7              Los Angeles          USA
# 8           Salt Lake City          USA
# 9                 Helsinki          FIN
# 10             Lake Placid          USA
# 11                  Sydney          AUS
# 12                 Atlanta          USA
# 13               Stockholm          SWE
# 14                   Sochi          RUS
# 15                  Nagano          JPN
# 16                  Torino          ITA
# 17                 Beijing          CHN
# 18          Rio de Janeiro          BRA
# 19                  Athina          GRE
# 20            Squaw Valley          USA
# 21               Innsbruck          SUI
# ...

# %%
noc_df.to_sql(name='host_cities', con=engine)
